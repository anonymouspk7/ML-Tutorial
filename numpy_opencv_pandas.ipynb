# %%
import numpy as np

# %%
a = np.array([1,2,3,4])
print(a)
print(type(a))
print(a.shape)
b = np.array([[1,2,3,4],[5,6,7,8]])
print(b)
print(type(b))
print(b.shape)
print(b.T)

print(np.dot(b,b.T))

matrix = np.random.randint(60,99,(5,5))
print(matrix)
print(np.max(matrix))
print(np.min((matrix)))
# Out:
# [1 2 3 4]
# <class 'numpy.ndarray'>
# (4,)
# [[1 2 3 4]
#  [5 6 7 8]]
# <class 'numpy.ndarray'>
# (2, 4)
# [[1 5]
#  [2 6]
#  [3 7]
#  [4 8]]
# [[ 30  70]
#  [ 70 174]]
# [[93 71 94 93 81]
#  [98 70 65 85 68]
#  [91 87 96 81 87]
#  [81 60 63 85 68]
#  [76 88 70 97 69]]
# 98
# 60

# %%
print(np.dot(b,b.T))
# Out:
# [[ 30  70]
#  [ 70 174]]

# %%
a = np.array([0,1,1,4,4,2,3,7,9,9,-21,21])
print(np.argmin(a))   ##basically it tells the index of minimum value
print(np.unique(a,return_counts = True))   ##print the unique elements in a sorted manner nd frequency of the elmt
# Out:
# 10
# (array([-21,   0,   1,   2,   3,   4,   7,   9,  21]), array([1, 1, 2, 1, 1, 2, 1, 2, 1]))

# %%
b = np.unique(a,return_counts = True)
print(b[0])
print(b[1])
# Out:
# [-21   0   1   2   3   4   7   9  21]
# [1 1 2 1 1 2 1 2 1]

# %%
#PROGRAM TO FIND THE MAXIMUM OCCURING ELEMENT IN A ARRAY
arr = np.array([5,6,4,9,5,2,2,2,2,3,4,6,3,4,3,888,66,55])
unq = np.unique(arr,return_counts = True)
print(unq)
idx = np.argmax(unq[1])
print(idx)
element = unq[0][idx]
print(element)
# Out:
# (array([  2,   3,   4,   5,   6,   9,  55,  66, 888]), array([4, 3, 3, 2, 2, 1, 1, 1, 1]))
# 0
# 2

# %%
#SLICING OF ARRAYS
print(matrix)
print(matrix[0:2,0:2])
# Out:
# [[93 71 94 93 81]
#  [98 70 65 85 68]
#  [91 87 96 81 87]
#  [81 60 63 85 68]
#  [76 88 70 97 69]]
# [[93 71]
#  [98 70]]

# %%
### 3.DATA VISUALISATION

# %%
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,3,4,5,6,7,8])
y = x**2 + 3
print(y)
# Out:
# [ 4  7 12 19 28 39 52 67]

# %%
plt.style.use("seaborn-deep")
plt.title("MY FIRST PLOT")
plt.plot(x,x**2 +3,label="STOCK PRICE")
plt.plot(x,x**2,label="STOCK PRICE 2")
plt.xlabel("time stamp")
plt.ylabel("price of stock")
plt.legend()
plt.show()

# %%
plt.style.available
# Out:
# ['grayscale',
#  'seaborn-whitegrid',
#  'classic',
#  'bmh',
#  'seaborn-paper',
#  'seaborn-dark-palette',
#  'ggplot',
#  'seaborn-bright',
#  'seaborn',
#  'seaborn-muted',
#  '_classic_test',
#  'seaborn-pastel',
#  'tableau-colorblind10',
#  'seaborn-ticks',
#  'seaborn-colorblind',
#  'seaborn-deep',
#  'Solarize_Light2',
#  'seaborn-talk',
#  'seaborn-white',
#  'seaborn-notebook',
#  'fast',
#  'seaborn-poster',
#  'dark_background',
#  'fivethirtyeight',
#  'seaborn-darkgrid',
#  'seaborn-dark']

# %%
plt.style.use("dark_background")
plt.title("MY SCATTER PLOT")
plt.scatter(x,x**2 +3,label="STOCK PRICE")
plt.scatter(x,x**2,label="STOCK PRICE 2")
plt.xlabel("time stamp")
plt.ylabel("price of stock")
plt.legend()
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/home/anonymous_pk7/anaconda3/cv.jpg')
rgb_image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
gray_image = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
print(img)
# Out:
# [[[192 207 226]
#   [192 207 226]
#   [192 207 226]
#   ...
#   [ 59 120 140]
#   [ 60 121 141]
#   [ 59 120 140]]
#
#  [[190 205 224]
#   [190 205 224]
#   [190 205 224]
#   ...
#   [ 57 118 138]
#   [ 57 118 138]
#   [ 56 117 137]]
#
#  [[188 203 222]
#   [188 203 222]
#   [188 203 222]
#   ...
#   [ 55 116 136]
#   [ 53 114 134]
#   [ 53 114 134]]
#
#  ...
#
#  [[ 22  30  47]
#   [ 24  32  49]
#   [ 24  34  51]
#   ...
#   [150 114  84]
#   [150 114  84]
#   [150 114  84]]
#
#  [[ 25  32  49]
#   [ 28  36  53]
#   [ 31  41  58]
#   ...
#   [150 114  84]
#   [150 114  84]
#   [150 114  84]]
#
#  [[ 28  35  52]
#   [ 33  41  58]
#   [ 37  47  64]
#   ...
#   [150 114  84]
#   [150 114  84]
#   [150 114  84]]]

# %%
print(img.shape)
# Out:
# (4000, 6000, 3)

# %%
plt.imshow(img)

# %%
plt.imshow(rgb_image)

# %%
plt.imshow(gray_image)
plt.axis("off")
# Out:
# (-0.5, 5999.5, 3999.5, -0.5)

# %%
crp_image = rgb_image[500:3000,1000:4000,]
plt.imshow(crp_image)

# %%
print(crp_image.shape)
# Out:
# (2500, 3000, 3)

# %%
total_pixel_size = crp_image.shape[0]*crp_image.shape[1]*3
print(total_pixel_size)
# Out:
# 22500000

# %%
##RESIZE THE IMAGE


crp_image2 = cv2.resize(crp_image,(1000,1000))
plt.show()
plt.title("TIGER"+str(crp_image2.shape))
plt.imshow(crp_image2)

# %%
##PANDAS - WORKING WITH TABULAR DATA

# %%
pokemons =  {
        "POKEMON_HEIGHT"  : np.random.randint(1,100,5),
        "POKEMON_WEIGHT"  : np.random.randint(50,150,5),
        "POKEMON_POWER"   : np.random.randint(200,250,5),
        
 }

# %%
pokemons
# Out:
# {'POKEMON_HEIGHT': array([ 9,  5, 83, 75, 86]),
#  'POKEMON_WEIGHT': array([112,  98, 119, 146, 105]),
#  'POKEMON_POWER': array([210, 235, 236, 229, 229])}

# %%
import pandas as pd

# %%
df = pd.DataFrame(pokemons)
print(df)
# Out:
#    POKEMON_HEIGHT  POKEMON_WEIGHT  POKEMON_POWER
# 0               9             112            210
# 1               5              98            235
# 2              83             119            236
# 3              75             146            229
# 4              86             105            229

# %%
df.head()
# Out:
#    POKEMON_HEIGHT  POKEMON_WEIGHT  POKEMON_POWER
# 0               9             112            210
# 1               5              98            235
# 2              83             119            236
# 3              75             146            229
# 4              86             105            229

# %%
##Create a CSV File
df.to_csv('pokemon_data.csv')

# %%
##Read a DataFrame
#-kaggle challenges--> CSV files

# %%
df = pd.read_csv('pokemon_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  POKEMON_HEIGHT  POKEMON_WEIGHT  POKEMON_POWER
# 0           0               9             112            210
# 1           1               5              98            235
# 2           2              83             119            236
# 3           3              75             146            229
# 4           4              86             105            229
